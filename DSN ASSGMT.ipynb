# %%
import pandas as pd
import numpy as np

# %%
fileName='dsn_data.csv'
filePath='C:/Users/Omolola/Documents/DSN'
fullFilePath='C:/Users/Omolola/Documents/DSN/dsn_data.csv'

# %%
dataFile=pd.read_csv(filePath +'/' + fileName)

# %%
dataFile
# Out:
#       Month  WeekOfMonth  DayOfWeek     Make AccidentArea DayOfWeekClaimed  \
# 0       Dec            5  Wednesday    Honda        Urban          Tuesday
# 1       Jan            3  Wednesday    Honda        Urban           Monday
# 2       Oct            5     Friday    Honda        Urban         Thursday
# 3       Jun            2   Saturday   Toyota        Rural           Friday
# 4       Jan            5     Monday    Honda        Urban          Tuesday
# ...     ...          ...        ...      ...          ...              ...
# 15415   Nov            4     Friday   Toyota        Urban          Tuesday
# 15416   Nov            5   Thursday  Pontiac        Urban           Friday
# 15417   Nov            5   Thursday   Toyota        Rural           Friday
# 15418   Dec            1     Monday   Toyota        Urban         Thursday
# 15419   Dec            2  Wednesday   Toyota        Urban         Thursday
#
#       MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  \
# ...

# %%
dataFile.describe()
# Out:
#         WeekOfMonth  WeekOfMonthClaimed           Age  FraudFound_P  \
# count  15420.000000        15420.000000  15420.000000  15420.000000
# mean       2.788586            2.693969     39.855707      0.059857
# std        1.287585            1.259115     13.492377      0.237230
# min        1.000000            1.000000      0.000000      0.000000
# 25%        2.000000            2.000000     31.000000      0.000000
# 50%        3.000000            3.000000     38.000000      0.000000
# 75%        4.000000            4.000000     48.000000      0.000000
# max        5.000000            5.000000     80.000000      1.000000
#
#        PolicyNumber     RepNumber    Deductible  DriverRating          Year
# count  15420.000000  15420.000000  15420.000000  15420.000000  15420.000000
# mean    7710.500000      8.483268    407.704280      2.487808   1994.866472
# std     4451.514911      4.599948     43.950998      1.119453      0.803313
# ...

# %%
df = pd.read_csv("C:/Users/Omolola/Documents/DSN/dsn_data.csv")
df.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Jan            5     Monday   Honda        Urban          Tuesday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
# 2          Nov                   2    Male       Married  ...       7 years
# 3          Jul                   1    Male       Married  ...   more than 7
# 4          Feb                   2  Female        Single  ...       5 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15420 non-null  object
#  1   WeekOfMonth           15420 non-null  int64
#  2   DayOfWeek             15420 non-null  object
#  3   Make                  15420 non-null  object
#  4   AccidentArea          15420 non-null  object
#  5   DayOfWeekClaimed      15420 non-null  object
#  6   MonthClaimed          15420 non-null  object
#  7   WeekOfMonthClaimed    15420 non-null  int64
#  8   Sex                   15420 non-null  object
#  9   MaritalStatus         15420 non-null  object
#  10  Age                   15420 non-null  int64
#  11  Fault                 15420 non-null  object
#  12  PolicyType            15420 non-null  object
#  13  VehicleCategory       15420 non-null  object
#  14  VehiclePrice          15420 non-null  object
# ...

# %%
#REMOVE IRRELEVANT DATA

# %%
df.columns
# Out:
# Index(['Month', 'WeekOfMonth', 'DayOfWeek', 'Make', 'AccidentArea',
#        'DayOfWeekClaimed', 'MonthClaimed', 'WeekOfMonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year',
#        'BasePolicy'],
#       dtype='object')

# %%
#wEEK OF THE MONTH
#DAY OF WEEK CLAIMED
df = df.drop("WeekOfMonth", axis=1)
df.head()
# Out:
#   Month  DayOfWeek    Make AccidentArea DayOfWeekClaimed MonthClaimed  \
# 0   Dec  Wednesday   Honda        Urban          Tuesday          Jan
# 1   Jan  Wednesday   Honda        Urban           Monday          Jan
# 2   Oct     Friday   Honda        Urban         Thursday          Nov
# 3   Jun   Saturday  Toyota        Rural           Friday          Jul
# 4   Jan     Monday   Honda        Urban          Tuesday          Feb
#
#    WeekOfMonthClaimed     Sex MaritalStatus  Age  ... AgeOfVehicle  \
# 0                   1  Female        Single   21  ...      3 years
# 1                   4    Male        Single   34  ...      6 years
# 2                   2    Male       Married   47  ...      7 years
# 3                   1    Male       Married   65  ...  more than 7
# 4                   2  Female        Single   27  ...      5 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent  AgentType  \
# 0          26 to 30                No             No   External
# ...

# %%
#MAKE OF THE CAR
df = df.drop("Make", axis=1)
df.head()
# Out:
#   Month  DayOfWeek AccidentArea DayOfWeekClaimed MonthClaimed  \
# 0   Dec  Wednesday        Urban          Tuesday          Jan
# 1   Jan  Wednesday        Urban           Monday          Jan
# 2   Oct     Friday        Urban         Thursday          Nov
# 3   Jun   Saturday        Rural           Friday          Jul
# 4   Jan     Monday        Urban          Tuesday          Feb
#
#    WeekOfMonthClaimed     Sex MaritalStatus  Age          Fault  ...  \
# 0                   1  Female        Single   21  Policy Holder  ...
# 1                   4    Male        Single   34  Policy Holder  ...
# 2                   2    Male       Married   47  Policy Holder  ...
# 3                   1    Male       Married   65    Third Party  ...
# 4                   2  Female        Single   27    Third Party  ...
#
#   AgeOfVehicle AgeOfPolicyHolder PoliceReportFiled  WitnessPresent  AgentType  \
# 0      3 years          26 to 30                No              No   External
# ...

# %%
#DayOfWeekClaimed	
df = df.drop("DayOfWeekClaimed", axis=1)
df.head()
# Out:
#   Month  DayOfWeek AccidentArea MonthClaimed  WeekOfMonthClaimed     Sex  \
# 0   Dec  Wednesday        Urban          Jan                   1  Female
# 1   Jan  Wednesday        Urban          Jan                   4    Male
# 2   Oct     Friday        Urban          Nov                   2    Male
# 3   Jun   Saturday        Rural          Jul                   1    Male
# 4   Jan     Monday        Urban          Feb                   2  Female
#
#   MaritalStatus  Age          Fault         PolicyType  ... AgeOfVehicle  \
# 0        Single   21  Policy Holder  Sport - Liability  ...      3 years
# 1        Single   34  Policy Holder  Sport - Collision  ...      6 years
# 2       Married   47  Policy Holder  Sport - Collision  ...      7 years
# 3       Married   65    Third Party  Sedan - Liability  ...  more than 7
# 4        Single   27    Third Party  Sport - Collision  ...      5 years
#
#   AgeOfPolicyHolder  PoliceReportFiled  WitnessPresent  AgentType  \
# ...

# %%
#WeekOfMonthClaimed
df = df.drop("WeekOfMonthClaimed", axis=1)
df.head()
# Out:
#   Month  DayOfWeek AccidentArea MonthClaimed     Sex MaritalStatus  Age  \
# 0   Dec  Wednesday        Urban          Jan  Female        Single   21
# 1   Jan  Wednesday        Urban          Jan    Male        Single   34
# 2   Oct     Friday        Urban          Nov    Male       Married   47
# 3   Jun   Saturday        Rural          Jul    Male       Married   65
# 4   Jan     Monday        Urban          Feb  Female        Single   27
#
#            Fault         PolicyType VehicleCategory  ... AgeOfVehicle  \
# 0  Policy Holder  Sport - Liability           Sport  ...      3 years
# 1  Policy Holder  Sport - Collision           Sport  ...      6 years
# 2  Policy Holder  Sport - Collision           Sport  ...      7 years
# 3    Third Party  Sedan - Liability           Sport  ...  more than 7
# 4    Third Party  Sport - Collision           Sport  ...      5 years
#
#    AgeOfPolicyHolder  PoliceReportFiled  WitnessPresent  AgentType  \
# ...

# %%
df = df.drop("WitnessPresent", axis=1)
df.head()
# Out:
#   Month  DayOfWeek AccidentArea MonthClaimed     Sex MaritalStatus  Age  \
# 0   Dec  Wednesday        Urban          Jan  Female        Single   21
# 1   Jan  Wednesday        Urban          Jan    Male        Single   34
# 2   Oct     Friday        Urban          Nov    Male       Married   47
# 3   Jun   Saturday        Rural          Jul    Male       Married   65
# 4   Jan     Monday        Urban          Feb  Female        Single   27
#
#            Fault         PolicyType VehicleCategory  ... PastNumberOfClaims  \
# 0  Policy Holder  Sport - Liability           Sport  ...               none
# 1  Policy Holder  Sport - Collision           Sport  ...               none
# 2  Policy Holder  Sport - Collision           Sport  ...                  1
# 3    Third Party  Sedan - Liability           Sport  ...                  1
# 4    Third Party  Sport - Collision           Sport  ...               none
#
#    AgeOfVehicle  AgeOfPolicyHolder  PoliceReportFiled  AgentType  \
# ...

# %%
# confimed and make sure all the reqired 
# columns have been removed
df.columns
# Out:
# Index(['Month', 'DayOfWeek', 'AccidentArea', 'MonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year',
#        'BasePolicy'],
#       dtype='object')

# %%
vdf = df.drop("MonthClaimed", axis=1)
df.head()
# Out:
#   Month  DayOfWeek AccidentArea MonthClaimed     Sex MaritalStatus  Age  \
# 0   Dec  Wednesday        Urban          Jan  Female        Single   21
# 1   Jan  Wednesday        Urban          Jan    Male        Single   34
# 2   Oct     Friday        Urban          Nov    Male       Married   47
# 3   Jun   Saturday        Rural          Jul    Male       Married   65
# 4   Jan     Monday        Urban          Feb  Female        Single   27
#
#            Fault         PolicyType VehicleCategory  ... AgeOfVehicle  \
# 0  Policy Holder  Sport - Liability           Sport  ...      3 years
# 1  Policy Holder  Sport - Collision           Sport  ...      6 years
# 2  Policy Holder  Sport - Collision           Sport  ...      7 years
# 3    Third Party  Sedan - Liability           Sport  ...  more than 7
# 4    Third Party  Sport - Collision           Sport  ...      5 years
#
#    AgeOfPolicyHolder  PoliceReportFiled  WitnessPresent  AgentType  \
# ...

# %%
df.columns
# Out:
# Index(['Month', 'DayOfWeek', 'AccidentArea', 'MonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year',
#        'BasePolicy'],
#       dtype='object')

# %%
#Deduplicate your data
# check the size of your dataset so you can 
# keep track of any row or datapoint that was removed
df.shape
# check the size of your dataset so
# Out:
# (15420, 29)

# %%
# The main of this section is to rename the different 
# class in our categorigal feature that were not properly named.
# or chanage the data type of a column

cat_features = {
    "Sex",
    "DriverRating",
    
}

for cat_feature in cat_features:
  print(df[cat_feature].unique())
# Out:
# [1 4 3 2]
# ['Female' 'Male']

# %%
df["DriverRating"]
# Out:
# 0        1
# 1        4
# 2        3
# 3        2
# 4        1
#         ..
# 15415    4
# 15416    3
# 15417    4
# 15418    4
# 15419    4
# Name: DriverRating, Length: 15420, dtype: int64

# %%
df['Sex']
# Out:
# 0        Female
# 1          Male
# 2          Male
# 3          Male
# 4        Female
#           ...
# 15415      Male
# 15416      Male
# 15417      Male
# 15418    Female
# 15419      Male
# Name: Sex, Length: 15420, dtype: object

# %%
# Firstky we idenity the colunms with
# missing values and their count

df.isnull().sum()
# Out:
# Month                   0
# DayOfWeek               0
# AccidentArea            0
# MonthClaimed            0
# Sex                     0
# MaritalStatus           0
# Age                     0
# Fault                   0
# PolicyType              0
# VehicleCategory         0
# VehiclePrice            0
# FraudFound_P            0
# PolicyNumber            0
# RepNumber               0
# Deductible              0
# DriverRating            0
# Days_Policy_Accident    0
# Days_Policy_Claim       0
# PastNumberOfClaims      0
# AgeOfVehicle            0
# AgeOfPolicyHolder       0
# PoliceReportFiled       0
# WitnessPresent          0
# AgentType               0
# NumberOfSuppliments     0
# AddressChange_Claim     0
# NumberOfCars            0
# Year                    0
# BasePolicy              0
# dtype: int64

# %%
mean_value=df["Age"].mean()

# %%
mean_value
# Out:
# 39.855706874189366

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.boxplot(df['Deductible'])
# Out:
# C:\Users\Omolola\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Deductible'>

# %%
sns.boxplot(df['DriverRating'])
#DriverRating
# Out:
# C:\Users\Omolola\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DriverRating'>
